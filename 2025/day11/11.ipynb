# %%
lines  = open('sample').read().strip().splitlines()
# lines

# %%
d = dict()
# with open('sample') as file:
with open('input') as file:
    while line := file.readline():
        parts = line.split()
        key = parts[0][:-1]
        vals = parts[1:]
        d[key] = vals
# d

# %%
from functools import cache

# %%
# start = "you"
# end = "out"
cnt = 0

# @cache
def follow(curr_pos, end):
    if curr_pos == end:
        return 1 
    # if curr_pos == "out":
    #     return 0
    
    c=0
    # print(curr_pos, end, d[curr_pos])
    for val in d[curr_pos]:
        c += follow(val, end)
    return c

follow("you", "out")
# print(follow("svr", "fft"))
# print(follow("fft", "dac"))
# print(follow("dac", "out"))
# print()
# print(follow("svr", "dac"))
# print(follow("dac", "fft"))
# print(follow("fft", "out"))
# Out:
# 688

# %%
6296*9252947*5034
# Out:
# 293263494406608
